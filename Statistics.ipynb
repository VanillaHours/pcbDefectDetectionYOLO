# %%
import os

# %%
image_files = []
os.chdir("dataset")
for filename in os.listdir(os.getcwd()):
    if filename.endswith(".txt"):
        with open(filename, 'r') as firstfile, open('data.txt','a') as secondfile:
            print(filename)
            for line in firstfile:
                secondfile.write(line)
# Out:
# 00041000.txt
# 00041001.txt
# 00041002.txt
# 00041003.txt
# 00041004.txt
# 00041005.txt
# 00041006.txt
# 00041007.txt
# 00041008.txt
# 00041009.txt
# 00041010.txt
# 00041011.txt
# 00041012.txt
# 00041013.txt
# 00041014.txt
# 00041015.txt
# 00041016.txt
# 00041017.txt
# 00041018.txt
# 00041019.txt
# 00041020.txt
# 00041021.txt
# 00041022.txt
# 00041023.txt
# 00041024.txt
# 00041025.txt
# 00041026.txt
# 00041027.txt
# 00041028.txt
# 00041029.txt
# 00041030.txt
# 00041031.txt
# 00041032.txt
# 00041033.txt
# 00041034.txt
# 00041035.txt
# 00041036.txt
# 00041037.txt
# 00041038.txt
# 00041039.txt
# 00041040.txt
# 00041041.txt
# 00041042.txt
# 00041043.txt
# 00041044.txt
# 00041045.txt
# 00041046.txt
# 00041047.txt
# 00041048.txt
# 00041049.txt
# 00041050.txt
# 00041051.txt
# 00041052.txt
# 00041053.txt
# 00041054.txt
# 00041055.txt
# 00041056.txt
# 00041057.txt
# 00041058.txt
# 00041059.txt
# 00041060.txt
# 00041061.txt
# 00041062.txt
# 00041063.txt
# 00041064.txt
# 00041065.txt
# ...

# %%
totalCount=0
d=[0,0,0,0,0,0]
with open('data.txt', 'r') as data:
    for line in data:
        totalCount+=1
        d[int(line[0])]+=1
#         print(line[0])
#         print(line)
        
print(c)
print(d)
# Out:
# 10013
# [1942, 1506, 1965, 1625, 1474, 1501]
